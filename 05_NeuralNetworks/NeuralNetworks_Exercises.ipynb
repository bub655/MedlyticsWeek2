# %% [markdown]
# # Neural Network Exercises
#
# In these exercises, you will be building your own artificial neural network and seeing how adding different types of layers can affect the validation/testing accuracy. This is based off of the simple neural network with Keras tutorial, so you can reference that for further explanations as well.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
# Out:
# 2024-07-17 18:26:20.810558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-17 18:26:20.994799: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-07-17 18:26:20.994829: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-07-17 18:26:21.042443: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-17 18:26:22.081976: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-07-17 18:26:22.082094: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-07-17 18:26:22.082109: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
os.system('wget https://raw.githubusercontent.com/MedlyticsUniversal/Data/main/Week2/spoken_digit_manual_features.csv')
# Out:
# --2024-07-17 18:26:23--  https://raw.githubusercontent.com/MedlyticsUniversal/Data/main/Week2/spoken_digit_manual_features.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 220478 (215K) [text/plain]
# Saving to: ‘spoken_digit_manual_features.csv.32’
#
#      0K .......... .......... .......... .......... .......... 23% 21.2M 0s
#     50K .......... .......... .......... .......... .......... 46% 26.1M 0s
#    100K .......... .......... .......... .......... .......... 69% 28.2M 0s
#    150K .......... .......... .......... .......... .......... 92% 27.8M 0s
#    200K .......... .....                                      100% 5.93M=0.01s
#
# 2024-07-17 18:26:23 (20.6 MB/s) - ‘spoken_digit_manual_features.csv.32’ saved [220478/220478]
# 0

# %% [markdown]
# ## Load Training Data and Pre-processed Features
#
# Your goal is to build a neural network that learns to classify which of the 5 speakers is recorded in a signal sample. Your prediction will be based off of features we've already pre-extracted for you and put into this CSV file: spectral centroid `SC`, spectral flatness `SF`, and maximum frequency `MF`.

# %%
# Load csv containing raw data, labels, and pre-processed features
spoken_df = pd.read_csv('spoken_digit_manual_features.csv', index_col = 0)
print(spoken_df.head(10))
print('\n')

# Set speakers
speakers = set(spoken_df['speaker'])
print(f'There are {len(speakers)} unique speakers in the dataset')
# Out:
#                 file  digit   speaker  trial           SC        SF  \
# 0   5_yweweler_8.wav      5  yweweler      8  1029.497959  0.397336
# 1    3_george_49.wav      3    george      4  1881.296834  0.387050
# 2  9_yweweler_44.wav      9  yweweler      4  1093.951856  0.394981
# 3  8_yweweler_33.wav      8  yweweler      3  1409.543285  0.487496
# 4      7_theo_34.wav      7      theo      3   887.361601  0.396825
# 5   1_jackson_45.wav      1   jackson      4  1007.568129  0.324100
# 6  6_yweweler_18.wav      6  yweweler      1  1286.701352  0.498813
# 7    9_george_35.wav      9    george      3  1405.092061  0.353083
# 8   9_jackson_32.wav      9   jackson      3  1172.899961  0.477907
# 9    8_george_26.wav      8    george      2  1959.977577  0.462901
#
#            MF
# 0  745.878340
# 1  323.943662
# 2  244.648318
# 3  392.350401
# 4  130.640309
# 5  216.306156
# 6  400.715564
# 7  447.239693
# 8  114.892780
# 9  320.537966
#
#
# There are 5 unique speakers in the dataset

# %%
# Make dictionary to convert from speaker names to indices
name2int_dict = {name: ind for (ind, name) in enumerate(set(spoken_df['speaker']))}

y_labels = spoken_df['speaker']
# Set y_labels to be indices of speaker
y_labels = [name2int_dict[name] for name in y_labels]

# %% [markdown]
# Split data into train, validation, and test sets and standardize:

# %%
# Downselect to only the 3 columns of the dataset we are learning from, aka the features
X_data = spoken_df[['SC', 'SF', 'MF']].to_numpy()

# Decide how large to make validation and test sets
n_val = 250
n_test = 250

# Shuffle data before partitioning
X_data, y_labels = shuffle(X_data, y_labels, random_state = 25)

# Partition
X_data_test, y_labels_test = X_data[:n_test,:], y_labels[:n_test]
X_data_val, y_labels_val = X_data[n_test:n_test+n_val,:], y_labels[n_test:n_test+n_val]
X_data_train, y_labels_train = X_data[n_test+n_val:,:], y_labels[n_test+n_val:]

# Scale data
scaler = StandardScaler()
X_data_train=scaler.fit_transform(X_data_train)
X_data_val = scaler.transform(X_data_val)
X_data_test = scaler.transform(X_data_test)

# %% [markdown]
# Converting labels to "one-hot" vectors:

# %%
# Convert labels to onehot
y_labels_train = tf.keras.utils.to_categorical(y_labels_train, 5)
y_labels_val =  tf.keras.utils.to_categorical(y_labels_val, 5)
y_labels_test =  tf.keras.utils.to_categorical(y_labels_test, 5)

training_set = tf.data.Dataset.from_tensor_slices((X_data_train, y_labels_train))
# Out:
# 2024-07-17 18:26:23.767297: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-07-17 18:26:23.767359: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-07-17 18:26:23.767384: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-af4e382a-c6a1-46d5-a014-268d0d4a7f76): /proc/driver/nvidia/version does not exist
# 2024-07-17 18:26:23.767790: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Additional Layers
#
# Before you get to building your own neural network, we'll show you some examples of additional layers you can potetially add that we didn't go over in the tutorial. After reading over our explanations/example code and going through documentation, you'll be testing some of these out by putting together a neural network yourself.

# %% [markdown]
# ### Dropout Layers
#
# Dropout layers randomly omit, or drop, some elements of the output vector from the layer, which helps prevent overfitting and can improve the generalization of your neural network. The dropout rate can be any number between 0 and 1.
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
#
# ```
# # Example
# d_r = 0.6
# tf.keras.layers.Dropout(rate=d_r)
# ```

# %% [markdown]
# ### Pooling Layers
#
# A pooling layer reduces dimensionality (the size of each feature map) and "compresses" information by combining several output elements. Two common functions used for pooling are:
# - **Average pooling**: calculating the average value for each patch on the feature map
# - **Max pooling**: calculating the maximum value for each patch of the feature map
#
# *Note: we won't apply pooling in this exercise notebook, but you'll be seeing more of it in future ones*
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool1D
#
# ```
# # Example
# tf.keras.layers.MaxPool1D(pool_size=1)
# ```

# %% [markdown]
# ### Activation Layers/Functions
#
# An activation function looks at each "neuron" in your neural network and determines whether it should be activated (fired) or not, based on the relevancy of the neuron's input to the model's predictions. Some different activation functions you could look at are:
# - **Softmax**: https://www.tensorflow.org/api_docs/python/tf/keras/layers/Softmax
# - **Sigmoid**: https://www.tensorflow.org/api_docs/python/tf/keras/activations/sigmoid
# - **Softplus**: https://www.tensorflow.org/api_docs/python/tf/keras/activations/softplus
# - **ReLU**: https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU
#
# ```
# # Example
# tf.keras.layers.Softmax()
# ```

# %% [markdown]
# ### Optimization Functions
#
# - **Adam**: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam
#     - Adam is computationally efficient, has little memory requirement, and is well suited for problems that are large in terms of data/parameter.
# - **Adagrad**: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad
#     - Adagrad is an optimizer that is best used for sparse data. Some of its benefits are that it converges more quickly and doesn't need manual adjustment of the hyperparameter "learning rate".
# - **SGD**: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD
#     - SGD is a **stochastic gradient descent** and momentum optimizer. SGD essentially helps gradient vectors move down loss functions towards the minimum point, leading to faster "converging."
# - **RMSprop**: https://keras.io/api/optimizers/rmsprop/
#     - As you may already know, the learning rate regulates how much the model can change based on the estimated error (which occurs every time the model's weights are updated). Instead of treating the learning rate as a hyperparamter, RMSprop is an optimization technique that relies on a changing, adaptive learning rate.
#
# ```
# # Example code
# l_r = .001
# tf.keras.optimizers.SGD(learning_rate=l_r)
# ```

# %% [markdown]
# ## Putting Together Your Neural Network
#
# Now you will experiment with adding different layers to your neural network. We've added some guiding comments to give you a place to start and test out, but we also strongly encourage you to go through all the documentation and use the Internet as well!

# %%
# Once you've gone through all the tests, play around with these rates to see if you can increase your accuracy.
l_r = .01
d_r = 0.5

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(8, input_shape=(3,), activation = tf.nn.relu))

# %% [markdown]
# ### Test 1

# %%
# Run this cell as it is
#model.add(tf.keras.layers.Dense(8, activation = tf.nn.relu))
#model.add(tf.keras.layers.Dense(8, activation = tf.nn.relu))

# Output dimension needs to be number of classes in order for each to get a score
#model.add(tf.keras.layers.Dense(5))

# NOW SKIP down to the section that compiles and trains your model and run those cells.
# Check the pseudo-test accuracy and see how well the bare minimum performed.

# %% [markdown]
# ### Test 2

# %%
# ADD activation layer here
#model.add(tf.keras.layers.Dense(8, activation=tf.nn.sigmoid))
# ADD activation layer here
#model.add(tf.keras.layers.Dense(8, activation = tf.nn.sigmoid))
# ADD activation layer here
#model.add(tf.keras.layers.Dense(8, activation = tf.nn.sigmoid))

# Output dimension needs to be number of classes in order for each to get a score
#model.add(tf.keras.layers.Dense(5))

# NOW SKIP down to the section that compiles and trains your model and re-run those cells.
# What do you notice about the testing/validation accuracy after test 2 in comparison to test 1?

# %% [markdown]
# ### Test 3

# %%
# ADD activation layer here
model.add(tf.keras.layers.Dense(16, activation = tf.nn.relu))
# ADD activation layer here
model.add(tf.keras.layers.Dense(16, activation = tf.nn.relu))
# ADD activation layer here 
model.add(tf.keras.layers.Dense(16, activation = tf.nn.relu))

model.add(tf.keras.layers.Dense(24, activation = tf.nn.relu))

# Output dimension needs to be number of classes in order for each to get a score
model.add(tf.keras.layers.Dense(5, tf.nn.softmax))

# ADD dropout layer here
tf.keras.layers.Dropout(rate=d_r)
# Now skip down to the section that compiles and trains your model and re-run those cells.
# What do you notice about the testing/validation accuracy after test 3 in comparison to tests 1 & 2?

# %% [markdown]
# ### Test 4
#
# Now go back down to the cell where you compiled your model and this time, change the optimizer. It's been set to `Adam` as default but as we showed you above, there are other functions that you can test out.

# %% [markdown]
# ## Compiling and Training Your Model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 32
#
#  dense_1 (Dense)             (None, 16)                144
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 24)                408
#
#  dense_5 (Dense)             (None, 5)                 125
#
# =================================================================
# Total params: 1,253
# Trainable params: 1,253
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.categorical_crossentropy, 
              optimizer = tf.keras.optimizers.Adam(learning_rate=l_r),
              metrics = ['accuracy'])

# %% [markdown]
# Specify number of epochs and batch size, and fit the model to data:

# %%
EPOCHS = 50
batch_size = 100

training_set = training_set.batch(batch_size) # Set batch size

def run_model(model, EPOCHS, training_set):
    for epoch in range(EPOCHS):
        for signals, labels in training_set:
            tr_loss, tr_accuracy = model.train_on_batch(signals, labels)
        val_loss, val_accuracy = model.evaluate(X_data_val, y_labels_val)
        print(('Epoch #%d\t Training Loss: %.2f\tTraining Accuracy: %.2f\t'
            'Validation Loss: %.2f\tValidation Accuracy: %.2f')
            % (epoch + 1, tr_loss, tr_accuracy,
            val_loss, val_accuracy))

run_model(model, EPOCHS, training_set)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 1.
W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:26:41.986352: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8883 - accuracy: 0.6640
# Epoch #43	 Training Loss: 0.79	Training Accuracy: 0.66	Validation Loss: 0.89	Validation Accuracy: 0.66
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8797 - accuracy: 0.6520
# Epoch #44	 Training Loss: 0.80	Training Accuracy: 0.66	Validation Loss: 0.88	Validation Accuracy: 0.65
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8871 - accuracy: 0.6480
# Epoch #45	 Training Loss: 0.80	Training Accuracy: 0.64	Validation Loss: 0.89	Validation Accuracy: 0.65
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9125 - accuracy: 0.6480
# Epoch #46	 Training Loss: 0.79	Training Accuracy: 0.66	Validation Loss: 0.91	Validation Accuracy: 0.65
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8863 - accuracy: 0.6560
# Epoch #47	 Training Loss: 0.79	Training Accuracy: 0.66	Validation Loss: 0.89	Validation Accuracy: 0.66
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8908 - accuracy: 0.6520
# Epoch #48	 Training Loss: 0.77	Training Accuracy: 0.65	Validation Loss: 0.89	Validation Accuracy: 0.65
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8790 - accuracy: 0.6560
# 2024-07-17 18:26:44.322119: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #49	 Training Loss: 0.79	Training Accuracy: 0.64	Validation Loss: 0.88	Validation Accuracy: 0.66
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8812 - accuracy: 0.6480
# Epoch #50	 Training Loss: 0.78	Training Accuracy: 0.65	Validation Loss: 0.88	Validation Accuracy: 0.65

# %%
# Check performance on test set
test_loss, test_accuracy = model.evaluate(X_data_test, y_labels_test)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9584 - accuracy: 0.6160

# %% [markdown]
# Now create your own model and/or modify the existing model, and try to find the highest, appropriate testing and validation accuracies!

# %%
l_r = .01
d_r = 0.6

model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.Dense(8, input_shape=(3,)))
model2.add(tf.keras.layers.Dense(10))
model2.add(tf.keras.layers.Dense(10, tf.nn.relu))
model2.add(tf.keras.layers.Dropout(rate=d_r))
model2.add(tf.keras.layers.Dense(5))
model2.compile(loss = tf.keras.losses.categorical_crossentropy, 
              optimizer = tf.keras.optimizers.Adam(learning_rate=l_r),
              metrics = ['accuracy'])   

run_model(model2, 50, training_set)
# Out:
# 2024-07-17 18:34:16.903554: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:16.951559: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:16.999583: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1480
# Epoch #1	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1480
# Epoch #2	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #3	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:18.244371: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:18.275260: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #4	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:18.715541: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:18.781770: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:18.831612: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #5	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:19.123585: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:19.314857: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# 2024-07-17 18:34:19.375576: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #6	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #7	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:20.063144: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:20.091556: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #8	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #9	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #10	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #11	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# 2024-07-17 18:34:22.086290: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:22.268980: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #12	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #13	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:22.903550: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:23.002572: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #14	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #15	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #16	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:24.592126: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1480
# Epoch #17	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:24.909469: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #18	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:25.471587: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:25.627554: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #19	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:26.147211: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:26.160548: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:26.216280: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:26.322434: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #20	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:26.600999: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #21	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 1/8 [==>...........................] - ETA: 0s - loss: nan - accuracy: 0.09382024-07-17 18:34:27.243550: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:27.259586: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:27.275539: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #22	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #23	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:27.986883: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:28.001942: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:28.101149: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #24	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.1480
# Epoch #25	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #26	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:29.968065: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #27	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #28	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:30.867675: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #29	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:31.291837: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:31.415557: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 1/8 [==>...........................] - ETA: 0s - loss: nan - accuracy: 0.09382024-07-17 18:34:31.560614: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:31.611563: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #30	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:32.084679: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #31	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:32.599259: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# 2024-07-17 18:34:32.875553: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #32	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:33.159340: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:33.331562: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# 2024-07-17 18:34:33.379583: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #33	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:33.611562: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #34	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:34.039565: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #35	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #36	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:35.359602: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #37	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:35.698734: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #38	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1480
# 2024-07-17 18:34:36.318818: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #39	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #40	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:36.962631: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #41	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #42	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:37.785218: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #43	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1480
# Epoch #44	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #45	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:39.055918: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1480
# Epoch #46	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:39.491652: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:34:39.620566: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #47	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1480
# 2024-07-17 18:34:40.119594: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #48	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #49	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15
# 2024-07-17 18:34:40.783574: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.1480
# Epoch #50	 Training Loss: nan	Training Accuracy: 0.19	Validation Loss: nan	Validation Accuracy: 0.15

# %%
# Once you've gone through all the tests, play around with these rates to see if you can increase your accuracy.
l_r = .01
d_r = 0.5

model3 = tf.keras.Sequential()
model3.add(tf.keras.layers.Dense(8, input_shape=(3,), activation = tf.nn.relu))

model3.add(tf.keras.layers.Dense(64, activation=tf.nn.relu))
model3.add(tf.keras.layers.Dense(32, activation=tf.nn.relu))
model3.add(tf.keras.layers.Dropout(rate=.2))

model3.add(tf.keras.layers.Dense(5, tf.nn.softmax))
model3.compile(loss = tf.keras.losses.categorical_crossentropy, 
              optimizer = tf.keras.optimizers.Adam(learning_rate=l_r),
              metrics = ['accuracy'])   

run_model(model3, 40, training_set)
test_loss, test_accuracy = model3.evaluate(X_data_test, y_labels_test)
# Out:
# 2024-07-17 18:33:25.555632: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1492 - accuracy: 0.5640
# Epoch #1	 Training Loss: 1.17	Training Accuracy: 0.52	Validation Loss: 1.15	Validation Accuracy: 0.56
# 2024-07-17 18:33:26.287574: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:26.379593: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0987 - accuracy: 0.5640
# Epoch #2	 Training Loss: 1.08	Training Accuracy: 0.54	Validation Loss: 1.10	Validation Accuracy: 0.56
# 2024-07-17 18:33:26.671571: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:26.872564: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0378 - accuracy: 0.5960
# Epoch #3	 Training Loss: 1.10	Training Accuracy: 0.48	Validation Loss: 1.04	Validation Accuracy: 0.60
# 2024-07-17 18:33:27.155572: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:27.351563: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0260 - accuracy: 0.5960
# 2024-07-17 18:33:27.510971: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #4	 Training Loss: 1.06	Training Accuracy: 0.51	Validation Loss: 1.03	Validation Accuracy: 0.60
# 2024-07-17 18:33:27.723552: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:27.811391: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:27.871634: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:27.922523: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:27.969487: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0163 - accuracy: 0.6040
# Epoch #5	 Training Loss: 1.04	Training Accuracy: 0.53	Validation Loss: 1.02	Validation Accuracy: 0.60
# 2024-07-17 18:33:28.284047: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:28.369208: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0042 - accuracy: 0.6080
# Epoch #6	 Training Loss: 1.04	Training Accuracy: 0.53	Validation Loss: 1.00	Validation Accuracy: 0.61
# 2024-07-17 18:33:28.799460: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9982 - accuracy: 0.6080
# 2024-07-17 18:33:29.072978: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #7	 Training Loss: 0.98	Training Accuracy: 0.55	Validation Loss: 1.00	Validation Accuracy: 0.61
# 2024-07-17 18:33:29.387856: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:29.427561: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9644 - accuracy: 0.6280
# 2024-07-17 18:33:29.713724: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:29.866743: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch #8	 Training Loss: 1.00	Training Accuracy: 0.59	Validation Loss: 0.96	Validation Accuracy: 0.63
# 2024-07-17 18:33:29.963098: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:30.012074: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:30.078372: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-07-17 18:33:30.095547: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9506 - accuracy: 0.6200
# 2024-07-17 18:33:30.169395: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# Epoch